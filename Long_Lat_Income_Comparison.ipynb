# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import random
# %matplotlib notebook
from numpy.polynomial.polynomial import polyfit

file = "kaggleincome.csv"
df_main = pd.read_csv(file,engine = "python")
df_main.head()
# Out:
#         id  State_Code State_Name State_ab          County            City  \
# 0  1011000           1    Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL  Barbour County      Louisville
# 2  1011020           1    Alabama       AL   Shelby County      Columbiana
# 3  1011030           1    Alabama       AL   Mobile County         Satsuma
# 4  1011040           1    Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#          Lat        Lon   Mean  Median  Stdev        sum_w
# 0  30.771450 -88.079697  38773   30506  33101  1638.260513
# 1  31.708516 -85.611039  37725   19528  43789   258.017685
# 2  33.191452 -86.615618  54606   31930  57348   926.031000
# 3  30.874343 -88.009442  63919   52814  47707   378.114619
# 4  30.250913 -88.171268  77948   67225  54270   282.320328

# %%
df_main = df_main[(df_main["Lat"] > 25) & (df_main["Lat"] < 50)]
df_main = df_main.round({'Lat': 0, 'Lon': 0})
df_main["Number of Households"] = df_main["sum_w"] / df_main["Mean"]
df_main_grpby_lat = df_main.groupby(["Lat"]).sum()
df_main_grpby_lat["Mean Income"] = df_main_grpby_lat["sum_w"] / df_main_grpby_lat["Number of Households"]
df_main_grpby_lat.plot( y=["Mean Income"],kind="line")

x = ("Lat")
y = ("Latitude")

# Fit with polyfit
#b, m = polyfit(x, y, 1)
#plt.plot(x, y, '.')
#plt.plot(x, b + m * x, '-')
#plt.show()


plt.title("Income vs Lattitude")
plt.ylabel("Mean Income")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set the limits for the X and Y axes
plt.xlim(35,50)
plt.ylim(50000,65000)
plt.show()

# %%
plt.savefig(.png)
# Out:
#   File "<ipython-input-4-5176f2d9f6cc>", line 1
#     plt.savefig(.png)
#                 ^
# SyntaxError: invalid syntax

# %%
#regression line
from scipy.stats import linregress
from scipy import stats
import numpy as np

x = np.arange(0,10,1)
y = [30, 35, 40, 45, 50]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
line = slope*x+intercept
plt.plot(x, line, 'r', label='fitted line')

#x_axis = np.arange(0,10,1)
#income = [28, 33, 38, 43, 48]

#(slope, intercept,_,_ ,_ ) = linregress(x_axis, income)
#fit = slope * x_axis + intercept
plt.show()

# %%
df_main = df_main[(df_main["Lon"] < -66.0) & (df_main["Lon"] > -124.0)]
df_main = df_main.round({'Lat': 0, 'Lon': 0})
df_main["Number of Households"] = df_main["sum_w"] / df_main["Mean"]
df_main_grpby_lon = df_main.groupby(["Lon"]).sum()
df_main_grpby_lon["Mean Income"] = df_main_grpby_lon["sum_w"] / df_main_grpby_lon["Number of Households"]
df_main_grpby_lon.plot( y=["Mean Income"],kind="line")


df_main.head()

# x = ("Lon")
# y = ("Longitude")

# Fit with polyfit
# b, m = polyfit(x, y, 1)
# plt.plot(x, y, '.')
# plt.plot(x, b + m * x, '-')
# plt.show()


# plt.title("Income vs Longitude")
# plt.ylabel("Mean Income")
# plt.xlabel("Longitude")
# plt.grid(True)
# plt.show()
# Out:
#         id  State_Code State_Name State_ab          County            City  \
# 0  1011000           1    Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL  Barbour County      Louisville
# 2  1011020           1    Alabama       AL   Shelby County      Columbiana
# 3  1011030           1    Alabama       AL   Mobile County         Satsuma
# 4  1011040           1    Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#     Lat   Lon   Mean  Median  Stdev        sum_w  Number of Households
# 0  31.0 -88.0  38773   30506  33101  1638.260513              0.042253
# 1  32.0 -86.0  37725   19528  43789   258.017685              0.006839
# 2  33.0 -87.0  54606   31930  57348   926.031000              0.016958
# 3  31.0 -88.0  63919   52814  47707   378.114619              0.005916
# 4  30.0 -88.0  77948   67225  54270   282.320328              0.003622
